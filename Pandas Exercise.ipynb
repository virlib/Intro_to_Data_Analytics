# %%
import pandas as pd
import numpy as np

# %%
pd.Series()
# Out:
# Series([], dtype: object)

# %%
X= ['A', 'B', 'C']
Y= pd.Series(X, index=[1,2,3])

# %%
Y
# Out:
# 1    A
# 2    B
# 3    C
# dtype: object

# %%
Y.name='My letters'

# %%
Y.values
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %%
Y.head(1)
# Out:
# 1    A
# Name: My letters, dtype: object

# %%
Y.iloc[0]
# Out:
# 'A'

# %%
Y[1]
# Out:
# 'A'

# %%
Y.loc[1]
# Out:
# 'A'

# %%
Y.iloc[-1]
# Out:
# 'C'

# %%
Y.index= ['first', 'second', 'third']

# %%
Y[-1]
# Out:
# <ipython-input-95-e8d17dfbff73>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Y[-1]
# 'C'

# %%
Y[1]
# Out:
# <ipython-input-96-7cb65255aa5e>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Y[1]
# 'B'

# %% [markdown]
# Reverse positions

# %%
Y[::-1]
# Out:
# third     C
# second    B
# first     A
# Name: My letters, dtype: object

# %%
pd.Series(Y, dtype=float)
# Out:
# first     A
# second    B
# third     C
# Name: My letters, dtype: object

# %%
X=pd.Series(['1', '2'])
X.dtype
# Out:
# dtype('O')

# %%
pd.Series(X, dtype=int)
# Out:
# 0    1
# 1    2
# dtype: int64

# %%
X=pd.Series(np.array([1,2,3,6,2, 4]))
X.dtype
# Out:
# dtype('int64')

# %%
X.sort_values()
# Out:
# 0    1
# 1    2
# 4    2
# 2    3
# 5    4
# 3    6
# dtype: int64

# %%
X[4]=10
X
# Out:
# 0     1
# 1     2
# 2     3
# 3     6
# 4    10
# 5     4
# dtype: int64

# %%
X[X <5]
# Out:
# 0    1
# 1    2
# 2    3
# 5    4
# dtype: int64

# %% [markdown]
# DATAFRAME

# %%
import matplotlib.pyplot as plt

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]
marvel_df= pd.DataFrame(marvel_data, columns=['name', 'sex', 'year_launched'])

# %%
marvel_df.index= marvel_df['name']

# %%
marvel_df.drop(['Vision', 'Namor'])
# Out:
#                               name     sex  year_launched
# name
# Spider-Man              Spider-Man    male           1962
# Captain America    Captain America    male           1941
# Wolverine                Wolverine    male           1974
# Iron Man                  Iron Man    male           1963
# Thor                          Thor    male           1963
# Thing                        Thing    male           1961
# Mister Fantastic  Mister Fantastic    male           1961
# Hulk                          Hulk    male           1962
# Beast                        Beast    male           1963
# Invisible Woman    Invisible Woman  female           1961
# Storm                        Storm  female           1975
# Hawkeye                    Hawkeye    male           1964
# Daredevil                Daredevil    male           1964
# Doctor Strange      Doctor Strange    male           1963
# Hank Pym                  Hank Pym    male           1962
# ...

# %%
marvel_df.iloc[::-1]
# Out:
#                               name     sex  year_launched
# name
# Vision                      Vision    male           1968
# Black Widow            Black Widow  female           1964
# Wasp                          Wasp  female           1963
# Scarlet Witch        Scarlet Witch  female           1964
# Hank Pym                  Hank Pym    male           1962
# Doctor Strange      Doctor Strange    male           1963
# Daredevil                Daredevil    male           1964
# Hawkeye                    Hawkeye    male           1964
# Namor                        Namor    male           1939
# Storm                        Storm  female           1975
# Invisible Woman    Invisible Woman  female           1961
# Beast                        Beast    male           1963
# Hulk                          Hulk    male           1962
# Mister Fantastic  Mister Fantastic    male           1961
# Thing                        Thing    male           1961
# ...

# %%
marvel_df.iloc[1:-1:2]
# Out:
#                             name     sex  year_launched
# name
# Captain America  Captain America    male           1941
# Iron Man                Iron Man    male           1963
# Thing                      Thing    male           1961
# Hulk                        Hulk    male           1962
# Invisible Woman  Invisible Woman  female           1961
# Namor                      Namor    male           1939
# Daredevil              Daredevil    male           1964
# Hank Pym                Hank Pym    male           1962
# Wasp                        Wasp  female           1963

# %%
marvel_df.loc['Captain America':'Wasp':2]
# Out:
#                             name     sex  year_launched
# name
# Captain America  Captain America    male           1941
# Iron Man                Iron Man    male           1963
# Thing                      Thing    male           1961
# Hulk                        Hulk    male           1962
# Invisible Woman  Invisible Woman  female           1961
# Namor                      Namor    male           1939
# Daredevil              Daredevil    male           1964
# Hank Pym                Hank Pym    male           1962
# Wasp                        Wasp  female           1963

# %%
marvel_df['sex'].head()
# Out:
# name
# Spider-Man         male
# Captain America    male
# Wolverine          male
# Iron Man           male
# Thor               male
# Name: sex, dtype: object

# %%
marvel_df['year_launched'].iloc[::-1]
# Out:
# name
# Vision              1968
# Black Widow         1964
# Wasp                1963
# Scarlet Witch       1964
# Hank Pym            1962
# Doctor Strange      1963
# Daredevil           1964
# Hawkeye             1964
# Namor               1939
# Storm               1975
# Invisible Woman     1961
# Beast               1963
# Hulk                1962
# Mister Fantastic    1961
# Thing               1961
# Thor                1963
# Iron Man            1963
# Wolverine           1974
# Captain America     1941
# Spider-Man          1962
# Name: year_launched, dtype: int64

# %%
marvel_df['years_since']= 2024- marvel_df['year_launched']
marvel_df.head()
# Out:
#                             name   sex  year_launched  years_since
# name
# Spider-Man            Spider-Man  male           1962           62
# Captain America  Captain America  male           1941           83
# Wolverine              Wolverine  male           1974           50
# Iron Man                Iron Man  male           1963           61
# Thor                        Thor  male           1963           61

# %%
marvel_df[marvel_df['sex']=='male']['name']
# Out:
# name
# Spider-Man                Spider-Man
# Captain America      Captain America
# Wolverine                  Wolverine
# Iron Man                    Iron Man
# Thor                            Thor
# Thing                          Thing
# Mister Fantastic    Mister Fantastic
# Hulk                            Hulk
# Beast                          Beast
# Namor                          Namor
# Hawkeye                      Hawkeye
# Daredevil                  Daredevil
# Doctor Strange        Doctor Strange
# Hank Pym                    Hank Pym
# Vision                        Vision
# Name: name, dtype: object

# %%
marvel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Spider-Man to Vision
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           20 non-null     object
#  1   sex            20 non-null     object
#  2   year_launched  20 non-null     int64
#  3   years_since    20 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 1.3+ KB

# %%
marvel_df.describe()
# Out:
#        year_launched  years_since
# count      20.000000    20.000000
# mean     1961.850000    62.150000
# std         8.405982     8.405982
# min      1939.000000    49.000000
# 25%      1961.750000    60.000000
# 50%      1963.000000    61.000000
# 75%      1964.000000    62.250000
# max      1975.000000    85.000000

# %%
marvel_df
# Out:
#                               name     sex  year_launched  years_since
# name
# Spider-Man              Spider-Man    male           1962           62
# Captain America    Captain America    male           1941           83
# Wolverine                Wolverine    male           1974           50
# Iron Man                  Iron Man    male           1963           61
# Thor                          Thor    male           1963           61
# Thing                        Thing    male           1961           63
# Mister Fantastic  Mister Fantastic    male           1961           63
# Hulk                          Hulk    male           1962           62
# Beast                        Beast    male           1963           61
# Invisible Woman    Invisible Woman  female           1961           63
# Storm                        Storm  female           1975           49
# Namor                        Namor    male           1939           85
# ...

# %%
marvel_df.year_launched.plot()
# Out:
# <Axes: xlabel='name'>

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
btc = '/content/drive/My Drive/Project1_python/data/btc-market-price.csv'
a = pd.read_csv(btc)

# %%
a.head()
# Out:
#    2017-04-02 00:00:00  1099.169125
# 0  2017-04-03 00:00:00  1141.813000
# 1  2017-04-04 00:00:00  1141.600363
# 2  2017-04-05 00:00:00  1133.079314
# 3  2017-04-06 00:00:00  1196.307937
# 4  2017-04-07 00:00:00  1190.454250

# %%
a = pd.read_csv(btc, header= None)

# %%
a.columns= ['Timestamp', 'Price']

# %%
a.dtypes
# Out:
# Timestamp     object
# Price        float64
# dtype: object

# %% [markdown]
# CONVERTING DATATYPE OF TIMESTAMP TO DATE

# %%
pd.to_datetime(a['Timestamp'])
# Out:
# 0     2017-04-02
# 1     2017-04-03
# 2     2017-04-04
# 3     2017-04-05
# 4     2017-04-06
#          ...
# 360   2018-03-28
# 361   2018-03-29
# 362   2018-03-30
# 363   2018-03-31
# 364   2018-04-01
# Name: Timestamp, Length: 365, dtype: datetime64[ns]

# %%
a['Timestamp']=pd.to_datetime(a['Timestamp'])

# %%
a.set_index('Timestamp', inplace=True)

# %%
a.loc['2017-12-15']
# Out:
# Price    17771.9
# Name: 2017-12-15 00:00:00, dtype: float64

# %% [markdown]
# COMBINING ALL

# %%
b = pd.read_csv(
    '/content/drive/My Drive/Project1_python/data/btc-market-price.csv',
    header=None,
    names=['Timestamp', 'Price'],
    index_col=0,
    parse_dates=True
)

# %%
a.head()
# Out:
#                   Price
# Timestamp
# 2017-04-02  1099.169125
# 2017-04-03  1141.813000
# 2017-04-04  1141.600363
# 2017-04-05  1133.079314
# 2017-04-06  1196.307937

# %%
b.head()
# Out:
#                   Price
# Timestamp
# 2017-04-02  1099.169125
# 2017-04-03  1141.813000
# 2017-04-04  1141.600363
# 2017-04-05  1133.079314
# 2017-04-06  1196.307937

# %%
b.plot()
# Out:
# <Axes: xlabel='Timestamp'>

# %%
x=np.arange(-10, 11)

# %%
plt.plot(x, x ** 3)

# %%
plt.figure(figsize=(12, 6))
plt.plot(x, x ** 2)
plt.plot(x, -1 * (x ** 2))

# %%
eth= pd.read_csv('/content/drive/My Drive/Project1_python/data/eth-price.csv', parse_dates=True)
eth.head()
# Out:
#   Date(UTC)  UnixTimeStamp  Value
# 0  4/2/2017     1491091200  48.55
# 1  4/3/2017     1491177600  44.13
# 2  4/4/2017     1491264000  44.43
# 3  4/5/2017     1491350400  44.90
# 4  4/6/2017     1491436800  43.23

# %%
pd.to_datetime(eth['UnixTimeStamp']).head()
# Out:
# 0   1970-01-01 00:00:01.491091200
# 1   1970-01-01 00:00:01.491177600
# 2   1970-01-01 00:00:01.491264000
# 3   1970-01-01 00:00:01.491350400
# 4   1970-01-01 00:00:01.491436800
# Name: UnixTimeStamp, dtype: datetime64[ns]

# %% [markdown]
# CREATING BOTH BITCOIN AND ETHER GRAPH IN ONE PLOT

# %%
eth= pd.read_csv('/content/drive/My Drive/Project1_python/data/eth-price.csv', parse_dates=[0])
eth.dtypes
# Out:
# Date(UTC)        datetime64[ns]
# UnixTimeStamp             int64
# Value                   float64
# dtype: object

# %%
eth.set_index('Date(UTC)', inplace=True)

# %%
eth.head()
# Out:
#             UnixTimeStamp  Value
# Date(UTC)
# 2017-04-02     1491091200  48.55
# 2017-04-03     1491177600  44.13
# 2017-04-04     1491264000  44.43
# 2017-04-05     1491350400  44.90
# 2017-04-06     1491436800  43.23

# %%
prices=pd.DataFrame(index=b.index)

# %%
prices.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [2017-04-02 00:00:00, 2017-04-03 00:00:00, 2017-04-04 00:00:00, 2017-04-05 00:00:00, 2017-04-06 00:00:00]

# %%
prices['btc']= b['Price']
prices['eth']= eth['Value']

# %%
prices.plot()
# Out:
# <Axes: xlabel='Timestamp'>

# %%
prices.plot(figsize= (24, 12))
# Out:
# <Axes: xlabel='Timestamp'>

# %%
prices.loc['2017-12-01':'2017-12-31'].plot(figsize=(12, 6))
# Out:
# <Axes: xlabel='Timestamp'>
